# %% [markdown]
# ### Code used for preprocessing singular valued/categorical attributes

# %%
import pandas as pd

df = pd.read_csv("books_v5_sample2.csv")
lis = []
c = 0

dic = {'KÅbÅ Abe':'Kobo Abe',
       '村上真美子':'Mamiko Murakami',
       'Architecture for Humanity':'Kate Stohr',
       'Slavoj Å½iÅ¾ek':'Slavoj Zizek',
       '0 Strategic Rul':'Sun Tzu',
       'IrÃ¨ne NÃ©mirovsky':'Irane Namirovsky',
       'EugÃ¨ne Ionesco':'Euegene Ionesco',
       '80% DISCOUNT':'Rick Riordan',
       'S瞨en·Kierkegaard':'Soren Kierkegaard',
       'Elisabeth KÃ¼bler-Ross':'Elisabeth Kubler Ross',
       'LeoÅ¡ JanÃ¡Äek':'Leoa Janaaek',
       'Kimon NicolaÃ¯des':'Kimon Nicolaa Des',
       'ommunicationg Your Faith in a Style that Fits Y':'Bill Hybels',
       'Jalāl al-Dīn Rūmī':'Rumi',
       'hen Wendy Grew U':'J.M. Barrie',

      }

for i in range(0,6500):
    x = df.iloc[i]['author1_nationality']
    if pd.isnull(x):
        print(df.iloc[i]['isbn_13'],"  ",df.iloc[i]['book_title'],"\t\t",df.iloc[i]['author1_name'])
        c+=1
print(c)

# %%
# attempt to fill missing values of nationality of the author

from time import sleep
from webdriver_manager.chrome import ChromeDriverManager
from datetime import date 
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium import webdriver
import time
import pandas as pd 

niced = {}

lis = ["//div[contains(@class,'df_img df_atct')]/following-sibling::strong[1]",
       "//div[contains(@class,'rwrl rwrl_pri')]//strong[1]",
       "//div[contains(@class,'rwrl rwrl_sec')]//strong[1]",
       "//div[@class='df_da']//div[1]",
       "//p[@class='b_paractl']//strong",
       "//p[@class='b_paractl']//strong[1]",
       "//div[@id='sf_caption_sf_40']//div[1]",
       "//div[@id='sf_caption_sf_30']//div[1]",
       "//div[@id='sf_caption_sf_27']//div[1]"]
       
driver = webdriver.Chrome(ChromeDriverManager().install())       
df = pd.read_csv("books_v5_sample2.csv")
for i in range(0,6500):
    if pd.isnull(df.iloc[i]['author1_nationality']):
        flag = 0
        auth = df.iloc[i]['author1_name']
        isbn = df.iloc[i]['isbn_13']
        res  = ""
        url = "https://www.google.com"
#         url  = 'https://www.bing.com'
        driver.get(url)
        
        query = "{} author nationality".format(auth)
#         search_box = driver.find_element_by_xpath("//input[@type='search']")
        search_box = driver.find_element_by_xpath("//input[@title='Search']")
        search_box.send_keys(query)
        search_box.send_keys(Keys.RETURN)
        
        print("#{} Author for ISBN {}, {} - ".format(i,auth,isbn))

        for j in lis:
            try:
                print("I")
                res = driver.find_element_by_xpath(j).text
                flag = 1
                break
            except:
                continue

        if flag==1:
            print("Done")
            if 'America' in res:
                res = 'United States of America'
            elif 'Brit' in res:
                res = 'England'
            elif 'Eng' in res:
                res = 'England'
            print("Okay with {}, or want to correct this?".format(res))
            n = int(input())
            if n==0:
                res = input()
            else:
                pass
            
            df.at[i,'author1_nationality'] = res
            niced.update({isbn:res})

        else:
            print("Not found.")
            print("Okay with no value, or do you want to enter something?")
            n = int(input())
            if n==0:
                res = input()
                df.at[i,'author1_nationality'] = res
                niced.update({isbn:res})
            else:
                pass

        df.to_csv("books_v5_sample2.csv")

# %%
dic = {
    'Japanese':'Japan',
    "Slovenia'":'Slovenia',
    'Colobia':'Colombia',
    'American':'United States of America',
    'Norwegian':'Norway',
    'Scottish':'Scotland',
    'Jamaican':'Jamaica',
    'British India':'India',
    'Yugoslavian':'Yugoslavia',
    'Danish':'Denmark',
    'Kingdom of Prussia':'Germany',
    'Lebanese':'Lebanon',
    'Turkish':'Turkey',
    'Ancient Rome':'Italy',
    'Classical Athens':'Greece',
    'Irish':'Ireland',
    'Marilyn Pappano':'Italy',
    'Saxe-Weimar-Eisenach':'Germany',
    '9780140441376':'England',
    'Icelandic':'Iceland',
    'United Kingdom of Great Britain and Ireland':'England',
    'Czechoslovak':'Czechoslovakia',
    'Lithuanian':'Lithuania',
    'Soviet Union':'Russia',
    'Chinese':'China',
    'Dutch':'Netherlands',
    'Mexican':'Mexico',
    'Belgian':'Belgium',
    'Republic of Florence':'Italy',
    'Indian':'India',
    'Kingdom of Italy':'Italy',
    'Great Britain':'England',
    'Kingdom of the Netherlands':'Netherlands',
    'Kingdom of Prussia':'Germany',   
    "People's Republic of China":'China',
    'German Reich':'Germany',
    'Spanish':'Spain',
    'Brazilian':'Brazil',
    'Italian':'Italy',
    'Kingdom of France':'France',
    'English':'England',
    'Polish':'Poland',
    'Prussian':'Germany',
    'United States of Americ':'United States of America',
    'United Kingdom':'England',
    'Kingdom of England':'England',
    'Republic of Venice':'Italy',
    'Canadian':'Canada',
    'Australian':'Australia',
    'Austria-Hungary':'Austria',
    'Czech':'Czechoslovakia',
    'Halicarnassus':'Greece',
    ' MGH Institute .':'United States of America',
    'German':'Germany',
    'Russian Empire':'Russia',
    'Austrian':'Austria',
    'British':'England',
    'Lu':'Luxembourg',
    'Israeli':'Israel',
    'British Empire':'England',
    'Portuguese':'Portugal',
     'Cuban':'Cuba',
    'Bolivian':'Bolivia',
    'Dominica':'Dominican Republic',
    'Roman':'Roman Empire',
    'Swiss':'Switzerland',
    'German Empire':'Germany',
    'Russian':'Russia',
    'French':'France',
    'Egyptian':'Egypt',
    'Nigerian':'Nigeria',
    'Greek':'Greece'
}


lis = []
df = pd.read_csv("books_v5_sample2.csv")
for i in range(0,6500):
    x = df.iloc[i]['author1_nationality']
    if x=='England':
        df.at[i,'author1_nationality'] = 'Britain'
df.to_csv("books_v5_sample2.csv")

# %%
# correcting author names with special characters

lis_done = [3186,3195,3196,3197,3198,3199,3200,3210,3211,3212,3219,3279,3577,3745,3770,3774,3826,3824,3841,4041,4114,4453,4723,4764,4743,4784,4807,4876,1270,1170,1149,1141,1301,1312,1390,2213,2328,6420,6337,6285,6091,5947,5869,5773,5322,4041]
lis = [254,869,1006,1030,1330,1389,1455,1482,1713,2410,3768,4069,4117,4111,4762]
lis2 = []

dic = {
    
    'Night Shift':'[\'Stephen King\']',
    '[\'Saint Augustine (Bishop of Hippo.)\', \'Saint Augustine of Hippo\', \'Joseph Mary Leleu\']':'[\'Saint Augustine\',\'Joseph Leleu\']',
    'Meditations on First Philosophy':'[\'Rene Descartes\']',
    '[\'Dawn B. Sova\', \'Branko·Sou閏ek\']' : '[\'Dawn B. Sova\', \'Branko·Soulek\']',
    '[\'Otis Williams\', \'Patricia Romanowski\', \'Patricia Romanowski Bashe\']' : '[\'Otis Williams\',\'Patricia Romanowski Bashe\']',
    '[\'Thomas V.. Morris\', \'Thomas V. Morris\', \'Matt Morris\', \'William Irwin\']' : '[\'Thomas V. Morris\', \'Matt Morris\', \'William Irwin\']', 
    
    
    
    '[\'Saint Cyril (patriarch of Alexandria)\']' : '[\'Saint Cyril\']',
    '[\'Plato\', \'S Lombardo\', \'et al\', \'Paul Woodruff\']':'[\'Plato\',\'S Lombardo\',\'Paul Woodruff\']',
    '[\'DC Talk (Musical group)\', \'Voice of the Martyrs (Organization)\']':'[\'DC Talk\']',
    '[\'Dalai Lama XIV Bstan-ʼdzin-rgya-mtsho\', \'Howard C. Cutler\']':'[\'Dalai Lama\',\'Howard Cutler\']',
    '[\'Mariia\', \'Mother Mariia\']' : '[\'Mariia\']',
    '[\'East Bay Municipal Utility District (Calif.)\']' : '[\'East Bay Municipal Utility District California\']',
    '[\'Bruce Spizer\', \'Alan W Livingston\', \'Capitol Records, Inc.\']' : '[\'Bruce Spizer\',\'Alan W Livinston\']',
    '[\'Ronna Johnson\', \'Nancy McCampbell Grace\', \'Nancy M.. Grace\']' : '[\'Ronna Johnson\',\'Nancy McCampbell Grace\']',
    '[\'Gordon S Wood\', \'Institute of Early American History and Culture (Williamsburg, Va.)\']':'[\'Gordon S Wood\']',
    '[\'John Patrick Diggins\', \'Professor John Patrick Diggins\']' : '[\'John Patrick Diggins\']',
    'Return to the Labyrinth of Solitude':'[\'Octavio Paz\']',
    '[\'Sadegh Hedayat\', \'Ṣādiq Hidāyat\']' : '[\'Sadegh Hedayat\']',
    '[\'William Shakespeare\', \'Bruce Coville\', \'Hillsboro Public Libraries (Hillsboro, Or.). Youth Services Division.\']' : '[\'William Shakespeare\', \'Bruce Coville\']',
    '[\'Architecture for Humanity (Organization)\']':'[\'Architecture for Humanity\']',
    '[\'村上真美子\']':'[\'Momiko Murakami\']',
    '[\'村上龍\']':'[\'Ryu Murakami\']',
    '[\'武蔵·宮本\']':'[\'Miamoto Musashi\']',
    '[\'伊藤潤二\']':'[\'Junji Ito\']',
    'Jo\'s Boys':'[\'Louisia May Alcott\']',
    'Volume II: the Endgame':'[\'Derrick Jensen\']',
    'The Driver\'s Seat':'[\'Muriel Spark\']',
    '[\'Noam Chomsky\', \'Institute Professor & Professor of Linguistics (Emeritus) Noam Chomsky\']':'[\'Noam Chomsky\']',
    '[\"Fodor\'s Travel Publications, Inc. Staff\"]' : '[\'Fodor\'s Travel Publications\']',
    '[\'Michael F Roizen\', \'Mehmet C Oz\', \'Mehmet Oz\', \'Lisa Oz\', \'Ted Spiker\']':'[\'Michael F Roizen\', \'Mehmet C Oz\', \'Lisa Oz\', \'Ted Spiker\']',
    '[\'Paul Kengor\', \'Professor of Political Science and Executive Director of the Center for Vision and Values Paul Kengor, PH.D.\']':'[\'Paul Kengor\']',
    '[\'Saint Thomas (Aquinas)\', \'Thomas Aquinas\', \'Thomas\']' : '[\'Saint Thomas\']',
    '[\'Saint Thomas (Aquinas)\', \'Thomas Aquinas\']': '[\'Saint Thomas\']',
    '[\'Saint Thomas (Aquinas)\']': '[\'Saint Thomas\']',
    '[\'Fedor Mihajlovič Dostoevskij\', \'Fyodor Dostoyevsky\']':'[\'Fyodor Dostoyevsky\']',
    '[\'Иван Сергеевич Тургенев\']':'[\'Ivan Sergeyevich Turgenev\']',
    '[\'Honoré de Balzac\', \'Honore Balzac\']':'[\'Honore Balzac\']',
    '[\'Francois Voltaire\', \'Voltaire\']':'[\'Francois Voltaire\']',
    '[\'Иван Сергеевич Тургенев\', \'Leonard Schapiro\']':'[\'Ivan Sergeyevich Turgenev\', \'Leonard Schapiro\']',
    '[\'Ancius Boethius\', \'Boethius\']':'[\'Ancius Boethius\']',
    '[\'Emily Brontë\']':'[\'Emily Jane Bronte\']',
    '[\'Vladimir Nabokov\', \'Vladimir Vladimirovich Nabokov\']':'[\'Vladimir Vladimirovich Nabokov\']',
    '[\'Geraldine (Oriental Institute Pinch, Oxford University)\', \'Geraldine Pinch\']': '[\'Geraldine Pinch\']',
    '[\'Virginia Woolf\', \'Adeline Virginia Stephen Woolf\']':'[\'Virginia Woolf\']',
    'Vathek':'[\'Vathek\']',
    '[\'Miguel de Cervantes Saavedra\', \'Miguel de Cervantes\']':'[\'Miguel de Cervantes\']',
    'The Guilty River':'[\'Wilkie Collins\']',
    '[\'Leo Tolstoy\', \'graf Leo Tolstoy\']':'[\'Leo Tolstoy\']',
    '[\'Denis Diderot\', \'Professor of Modern French Literature David Coward\']':'[\'Denis Diderot\']',
    '[\'Leonardo Da Vinci\', \'Leonardo (da Vinci)\']':'[\'Leonardo Da Vinci\']',
    'When Wendy Grew Up':'[\'J. M. Barrie\']',
    '[\'Euripides\', \'Eyripidēs\', \'Reginald (Professor of English Gibbons, Northwestern University)\', \'Charles (Charles C. Klein Professor of the Classics Segal, Harvard University)\']':'[\'Euripides\']',
    '[\'Ted Steinberg\', \'Adeline Barry Davee Distinguished Professor of History and Professor of Law Ted Steinberg\', \'Ted (Professor of History and Law Steinberg, Case Western Reserve University)\']':'[\'Ted Steinberg\']',
    '[\'Nikolai Gogol\', \'Николай Васильевич Гоголь\']':'[\'Nikolai Vasilyevich Gogol\']',
    '[\'Oxford University Press\', \'TME.\']':'[\'Oxford University Press\']',
    '[\'Todd Gitlin\', \'Professor of Culture Journalism and Sociology Todd Gitlin\']':'[\'Todd Gitlin\']',
    'Slavoj Žižek':'[\'Slavoj Zizek\']',
    '[\'United States. Congress. House. Committee on Financial Services\']':'[\'US Congress Committee on Financial Services\']',
    'Communicationg Your Faith in a Style that Fits You':'[\'Bill Hybels\',\'Mark Mittelberg\']',
    '[\'International Conference on the Fantastic in the Arts 1997 Ft. lauder\', \'International Conference on the Fantastic in the Arts\']':'[\'International Conference on the Fantastic in Arts\']',
    '[\'Dalai Lama XIV Bstan-ʼdzin-rgya-mtsho\', \'Howard C. Cutler\']':'[\'Dalai Lama XIV\', \'Howard C. Cutler\']',
    'Queen of Sorcery':'[\'David Eddings\']',
    '[\'Naguib Mahfouz\', \'Najīb Maḥfūẓ\', \'William M. Hutchins\']':'[\'Naguib Mahfouz\',\'William M. Hutchins\']',
    '[\'Kobo Abe\', \'安部公房\']':'[\'Kobo Abe\']',
    '[\'William Hardy McNeill\', \'William McNeill\']':'[\'William Hardy McNeill\']',
    '[\'Najīb Maḥfūẓ\', \'محفوظ، نجيب،\', \'Naguib Mahfouz\']':'[\'Naguib Mahfouz\']',
    '[\'Donald Spoto\', \'Donald Spoto, M.A., Ph.D.\']' : '[\'Donald Spoto\']',
    'Texas! Chase':'[\'Sandra Brown\']',
    '[\'Ian McEwan\', \'Alexandria Library (Alexandria, Va.)\']' : '[\'Ian McEwan\']',
    '[\'Stephen Greenblatt\', \'Stephen Jay Greenblatt\']' : '[\'Stephen Greenblatt\']',
    '[\'Sir Arthur Conan Doyle, Sir\', \'Leslie S. Klinger\', \'Arthur Doyle\']':'[\'Arthur Conan Doyle, Sir\', \'Leslie S. Klinger\']',
    '[\'Harriet Beecher Stowe\', \'Professor Harriet Beecher Stowe\', \'Louis Henry Gates\']':'[\'Harriet Beecher Stowe\', \'Louis Henry Gates\']',
    '[\'Kip Thorne\', \'Kip S. Thorne\', \'Stephen Hawking\']':'[\'Kip Thorne\', \'Stephen Hawking\']',
    '[\'Gilbert / Gubar\']':'[\'Sandra Gilbert\',\'Susan Gubar\']',
    '[\'Emily Bronte\', \'Emily Brontë\']':'[\'Emily Bronte\']',
    '[\'Seuss, Dr.\', \'Roy McKie\', \'Theo LeSieg\', \'Robert Lopshire\']':'[\'Dr. Seuss\']',
    '[\'Seuss, Dr.\', \'Library of Congress. National Library Service for the Blind and Physically Handicapped.\']':'[\'Dr. Seuss\']',
    '[\'William Shakespeare\', \'Gwynne Blakemore Evans\', \'Irving Babbitt Professor of Comparative Literature Harry Levin\', \'Herschel Baker\', \'J. J. M. Tobin\', \'Anne Barton\', \'Heather Dubrow\', \'William T. Liston\', \'Frank Kermode\', \'Harry Levin\', \'Marie Edel\', \'Hallet Smith\', \'Charles H. Shattuck\']':'[\'William Shakespeare\']',
    '[\'Eric Carle\', \'Marshall Public Library (Marshall, Ill.)\', \'Eastern Illinois University. School of Family and Consumer Sciences.\', \'Eastern Illinois University. Technical Association of the Graphic Arts.\']':'[\'Eric Carle\']',
    '[\'Robert B. Parker\', \'Copyright Paperback Collection (Library of Congress)\']':'[\'Robert B. Parker\']',
    '[\'Jon Stewart\', \'The Writers of The Daily Show\']':'[\'Jon Stewart\']',
    '[\'J. R. Ward\', \'Jessica Bird Ward\']' : '[\'J. R. Ward\']',
    '[\'Emily Bronte\', \'Emily Brontë\']' : '[\'Emily Bronte\']',
    '[\'Howard E. Covington, Jr.\', \'The Biltmore Company\']':'[\'Howard E. Covington Jr.\']',
    '[\'Simon Goldhill\', \'Professor of Greek Literature and Culture and Fellow and Director of Studies in Classics Simon Goldhill\']':'[\'Simon Goldhill\']',
    '[\'Simon Goldhill\', \'Goldhill Simon\', \'Professor of Greek Literature and Culture and Fellow and Director of Studies in Classics Simon Goldhill\']':'[\'Simon Goldhill\']',
    '[\'Hobsbawm, E. J. Hobsbawm\', \'Eric Hobsbawm\', \'Terence Ranger\']':'[\'Eric Hobsbawm\',\'Terence Ranger\']'
}



def nice(inp):
    return '[\''+inp+'\']'

df = pd.read_csv("books_v5_sample2.csv")
for i in range(0,6500):
    if i in lis:
        print("The author here is  ",df.iloc[i]['authors'])
        print("Enter correction.")
        n = input()
        df.at[i,'authors'] = nice(n)
        
df.to_csv("books_v5_sample2.csv")

# %%
# correcting ISBN 10s

import pandas as pd

df = pd.read_csv("books_v5_spare.csv")
df.at[2818,'isbn_10'] = '0448416735'
df.at[5336,'isbn_10'] = '0929524357'
df.at[5351,'isbn_10'] = '094024456X'
# df.at[1248,'published_date'] = 2013
# df.at[2399,'published_date'] = 1975
# df.at[3410,'published_date'] = 1818
# df.at[3441,'published_date'] = 1976
# df.at[3768,'published_date'] = 1925
# df.at[3774,'published_date'] = 1930
# df.at[4906,'published_date'] = 1949
# df.at[6015,'published_date'] = 1915
# df.at[6195,'publisher'] = 'Pagefree Pub Inc.'
# df.at[6198,'publisher'] = 'Editions Julliard'
# df.at[6348,'publisher'] = 'Ace'
# df.at[6420,'publisher'] = 'Roberts Brothers'

df.to_csv("books_v5_spare.csv")
# lis = []
# c = 0
# for i in range(0,6500):
#     x = df.iloc[i]['page_count']
#     if pd.isnull(x):
#         print(df.iloc[i]['book_title'],"   ",df.iloc[i]['isbn_13'])
#         c+=1
#         lis.append(i)
# print(lis)
# print(c)

# %%
# correcting languages

import pandas as pd

lang = {'ko':'Korean','it':'Italian','fr':'French','en':'English','ru':'Russian','da':'Danish','es':'Spanish','la':'Latin'}
lis = list(lang.keys())
languages = ['ko','it','fr','en','ru','da','es','la']
language_codes = ['Korean','Italian','French','English','Russian','Danish','Spanish','Latin']
c = 0



df = pd.read_csv("books_v5_spare.csv")
for i in range(0,6500):
    x = df.iloc[i]['language']
    df.at[i,'language'] = lang[x]

df = df.iloc[0:6500,11:]
df.to_csv("books_v5_spare.csv")

# %%
#Maturity Rating

df = pd.read_csv("books_v5_spare.csv")
valid_lis = ['MATURE','NOT_MATURE']

for i in range(0,6500):
    if df.iloc[i]['maturity_rating'] == 'MATURE':
        df.at[i,'maturity_rating'] = 'Mature'
    else:
        df.at[i,'maturity_rating'] = 'Not Mature'
df.to_csv("books_v5_spare.csv")

# %%
import pandas as pd

history = []

contemporary = []

religious = []

social_commentary = []

psychology = []

mythology = []

health = []

fiction = []

literature = []

poems = []

crime = []

setup = {'Drama', "['Cooking, French']", "['American Wit And Humour']", "['Authors, Arab']", "['Business women']", "['Humor']", "['Design']", "['Survival']", "['Contests']", "['Horror']", "['Queens']", "['Presidents']", "['African Americans in radio broadcasting']", '224', "['Music']", "['Photography']", "['Abandoned mines']", "['Antiques & Collectibles']", "['Choice']", "['Study Aids']", "['Birthparents']", "['Communal living']", "['Literary Collections']", '199', "['Southern States']", 'Oxford University Press, USA', "['Large type books']", "['Autism']", "['Chick lit']", "['Air pilots']", "['Beats (Persons)']", "['Christmas stories']", "['Consumer behavior']", "['Imaginary wars and battles']", "['Cowboys']", "['Christian saints']", "['Rock musicians']", "['France']", "['Stone age']", "['Family life']", "['Games & Activities']", "['Cambridge (Mass.)']", "['Transportation']", '["Aesop\'s fables"]', "['Dragons']", "['Australia']", "['Mentally ill']", '292', "['Kinetic theory of gases']", 'Social Commentary', "['Graphic novels']", "['Bedtime']", "['George U. Wyper Fund']", "['Authors, American']", '361', "['Apartments']", "['Empiricism']", "['Englisch - Geschichte - Lyrik - Aufsatzsammlung']", "['Obesity']", 'Contemporary', "['Arithmetic']", 'Biography', "['Sea monsters']", "['Ballets']", "['Bombings']", "['Gay men']", '299', 'Religion', "['Epic literature']", "['Generals']", "['Actors']", "['Physics']", "['People with social disabilities']", "['Businesswomen']", '2004', "['Theology, Doctrinal']", "['Short stories, English']", "['Leadership']", "['Character']", '181', "['English language']", "['Dreams']", "['Sweet Valley (Imaginary place)']", "['Yoknapatawpha County (Imaginary place)']", "['Mars (Planet)']", "['Business enterprises']", "['Existentialism']", "['Language and languages']", 'Psychology', "['Brewing']", "['Motion picture plays']", "['Fairy tales, English']", "['Salem (Mass.)']", "['History, Modern']", "['Cornwall (England : County)']", "['Divorced women']", "['Cosmology']", "['Poets, American']", "['Short stories, American']", "['Fourth of July']", "['Friendship']", "['Costume']", "['Christianity']", "['Canadian wit and humor']", "['Essentialism (Philosophy)']", "['Beat generation']", "['Poets, Chilean']", "['COMICS & GRAPHIC NOVELS']", "['Existential psychotherapy']", "['Adult education']", "['Boarding schools']", "['Arthurian romances']", "['Detective and mystery stories, English']", "['Self-Help']", "['Chicago (Ill.)']", "['Angels']", "['Humorous stories, American']", "['Meditation']", "['Nanjing (Jiangsu Sheng, China)']", "['Curiosities and wonders']", "['Antisemitism']", "['Reducing diets']", "['Animals']", "['Art']", "['Confucianism']", "['Los Angeles (Calif.)']", "['Humorous stories']", "['Ireland']", "['China']", "['Antislavery movements']", '["Children\'s stories"]', "['Drenai (Imaginary place)']", '103', "['College attendance']", "['Explorers']", "['Educational tests and measurements']", "['Frontier and pioneer life']", "['Airplane crash survival']", "['War']", "['Tobruk, Battles of, 1941-1942']", "['Country life']", "['Aeneas (Legendary character)']", "['Novelists, American']", "['American wit and humor']", "['Boats and boating']", "['Interplanetary voyages']", "['Magic']", "['Ghost stories, American']", '131', "['Comics & Graphic Novels']", "['House & Home']", "['Essays']", "['Fantasy']", "['Human-animal relationships']", "['Sound effects books']", "['David Eddings']", "['Gardening']", "['Detective and mystery stories, English.']", "['Man-woman relationships']", "['Computers']", '["Alzheimer\'s disease"]', "['Bus travel']", "['Dangerously mentally ill']", "['Argentine literature']", "['Great Britain']", "['Heroes']", "['Euthanasia']", "['English']", '535', "['Christian life']", "['Farm life']", "['Civilization, Modern']", "['African American families']", "['Kyoto (Japan)']", "['Married people']", '1992', "['Canterbury (England)']", "['Electrons']", "['Teenagers']", "['Physicists']", "['Construction workers']", "['Civil law']", "['Yi jing']", "['Pigeons']", "['Acting']", "['Discworld (Imaginary place)']", "['Candy']", "['Sex']", "['Estados Unidos - Relaciones exteriores - 1945-1989']", "['True Crime']", "['Gardens']", "['Crafts & Hobbies']", "['Criminals']", "['Jews']", "['Authors, Italian']", "['Technology & Engineering']", "['Fantasy comic books, strips, etc']", "['Bibles']", "['Political leadership']", "['Family & Relationships']", "['Chocolate']", "['Mathematics']", "['Alienation (Social psychology)']", "['Horror tales']", "['Capitalism']", "['Black Death']", "['Alcoholics']", "['Audiobooks']", "['Canada']", "['New England']", "['English essays']", "['Ex-convicts']", "['Identity (Psychology)']", "['Prisoners of war']", "['Vietnam War, 1961-1975']", "['Church work with the poor']", '2005', "['Aged women']", "['Zoology']", "['Music trade']", "['City and town life']", "['Book burning']", "['Emperors']", "['Brothers and sisters']", "['Germany']", "['Fairy tales']", "['Cooking']", "['Conspiracies']", "['Botanique']", "['Bracelets']", "['Child analysis']", 'Oxford Paperbacks', "['Czech Republic']", 'History', '["Children\'s literature, French"]', "['Caterpillars']", "['Écrivains français - 18e siècle - Biographies']", '208', '217', "['Foreign Language Study']", "['Death']", "['Political science']", "['Action']", "['Beowulf']", "['Nineteen ninety-eight, A.D.']", 'Mythology', "['Castle Rock (Me. : Imaginary place)']", "['Africa']", "['Friendship in adolescence']", "['Humorous stories, English']", "['Grandmothers']", "['Men']", "['Crusades']", "['Life on other planets']", "['Authors, Cuban']", "['Apartment houses']", "['Cults']", "['Epidemics']", "['American wit and humor, Pictorial']", "['Europe']", "['Amyotrophic lateral sclerosis']", "['Divorce']", "['Napoleonic Wars, 1800-1815']", "['Adjustment (Psychology)']", "['Botswana']", "['Adventure stories']", "['Animal sounds']", "['Dysfunctional families']", "['England']", "['Zero (The number)']", "['Animals, Treatment of']", "['Psychology']", "['Horror tales, American']", "['Pets']", "['Short stories']", "['Film producers and directors']", "['Authors, English']", "['Insane, Criminal and dangerous']", "['Social action']", "['87th Precinct (Imaginary place)']", '["Children\'s stories, English"]', "['Adolescence']", "['LITERARY CRITICISM']", "['Agriculture']", "['Americans']", "['Computer programmers']", "['Adventure stories, English']", "['Apartment buildings']", "['Detective and mystery stories']", "['Allegories']", "['Feature films [DVD]']", "['Religion']", "['Confianza en sí mismo']", "['Apartheid']", "['Austria']", '450', "['Cider house rules. (Motion picture)']", "['Minimal brain dysfunction in children']", "['College stories']", 'Poetry', "['Blacks']", "['Balkan Peninsula']", "['Anger']", "['Chaleur - Transmission']", "['Reference']", "['Cats']", "['Cities and towns']", "['Science']", "['Erinyes (Greek mythology)']", "['Psycho (Motion picture : 1960)']", "['Automobile industry and trade']", "['Parenthood']", "['London (England)']", "['Comedy']", "['Popular culture']", "['Children of Holocaust survivors']", "['Mythology, Greek']", "['First loves']", 'Fiction', "['Fantasy.']", "['Igbo (African people)']", "['Crime investigation']", "['Atonement']", "['Human behavior']", "['African Americans']", "['Banks and banking, British']", "['Misogyny']", "['Sebastopol (Calif.)']", "['Literature']", "['Novelists, English']", "['Crime investigations']", "['Comic books, strips, etc']", "['History']", "['Architecture']", "['College students']", "['Cookbooks']", "['Badgers']", "['Oratory']", "['Nature']", "['Monetary policy']", "['Amazon River Region']", "['American literature']", "['Bereavement']", "['Metamorphosis']", "['Egyptologists']", "['Charriere Henri']", "['Books']", "['Sports & Recreation']", "['Mormon fundamentalism']", "['Handicapped youth']", "['Christmas']", "['Murder']", "['Cellists']", "['Cerebrovascular disease']", "['Boston (Mass.)']", "['Detective and mystery comic books, strips, etc']", "['Aboriginal Australians']", "['Cosmetics industry']", "['Disasters']", "['Outlaws']", "['Babysitters']", "['Love']", "['Bosnia and Hercegovina']", "['Amis, Kingsley']", "['Male friendship']", "['Adventure stories, American']", "['Sexual behavior surveys']", "['Aging']", "['RELIGION']", "['Buddhism']", "['Brothers']", "['College teachers']", "['Rock groups']", '["Children\'s plays"]', "['Scythians']", "['Horror stories.']", '398', "['Imperialism']", "['Cocaine industry']", "['Literary Criticism']", "['Rabbits']", "['Bail bond agents']", "['Animal sanctuaries']", "['Babytime resource']", "['Law']", "['Instrumental music']", "['Exorcism']", "['British']", '122', "['Divorced people']", "['Human-alien encounters']", "['Characters and characteristics in motion pictures']", "['Community life']", "['Cookery']", "['American essays']", "['Boys']", 'Health and Fitness', "['Animals, Mythical']", "['Emotional problems']", "['Rock music']", "['Behavior']"}
c = 0

for i in setup:
    c+=1
    print(c)
    if pd.isnull(i):
        literature.append(i)
    else:
        print("Enter the genre for",i)
        print("1.  History")
        print("2.  Contemporary")
        print("3.  Religious")
        print("4.  Social Commentary")
        print("5.  Psychology")
        print("6.  Mythology")
        print("7.  Health")
        print("8.  Fiction")
        print("9.  Literature")
        print("10. Poems")
        print("11. Crime")
        
        try:
            n = int(input())
            if n==1:
                history.append(i)
            if n==2:
                contemporary.append(i)
            if n==3:
                religious.append(i)
            if n==4:
                social_commentary.append(i)
            if n==5:
                psychology.append(i)
            if n==6:
                mythology.append(i)
            if n==7:
                health.append(i)
            if n==8:
                fiction.append(i)
            if n==9:
                literature.append(i)
            if n==10:
                poems.append(i)
            if n==11:
                crime.append(i)
            if n==0:
                continue
        except:
            print("Not done, moving on.")

# %%
#Genres
import pandas as pd


history = ["['Stone age']", "['Prisoners of war']", "['Antislavery movements']", "['History, Modern']", "['Cowboys']", "['Estados Unidos - Relaciones exteriores - 1945-1989']", "['Children of Holocaust survivors']", "['Bombings']", "['Vietnam War, 1961-1975']", "['Antiques & Collectibles']", "['Aeneas (Legendary character)']", "['Tobruk, Battles of, 1941-1942']", "['Euthanasia']", "['Napoleonic Wars, 1800-1815']", "['Nineteen ninety-eight, A.D.']", "['Airplane crash survival']", "['War']", "['Imaginary wars and battles']", "['Emperors']"]
contemporary = ['299', "['Badgers']", "['Rabbits']", "['Film producers and directors']", "['Kyoto (Japan)']", "['Canada']", '103', '2005', "['Outlaws']", "['China']", "['Educational tests and measurements']", "['Africa']", '535', "['Rock musicians']", "['Bosnia and Hercegovina']", "['Atonement']", "['Business enterprises']", "['Physics']", "['Apartment buildings']", "['College attendance']", "['Characters and characteristics in motion pictures']", "['Science']", "['Balkan Peninsula']", "['British']", "['Monetary policy']", "['Church work with the poor']", "['Boston (Mass.)']", "['Music']", "['Banks and banking, British']", "['Automobile industry and trade']", "['Authors, Arab']", "['Cambridge (Mass.)']", "['Salem (Mass.)']", '181', "['Bereavement']", "['Book burning']", "['Australia']", "['Arithmetic']", '122', "['Animals']", "['Foreign Language Study']", "['Actors']", "['Nanjing (Jiangsu Sheng, China)']", "['Audiobooks']", "['France']", "['Businesswomen']", "['Contests']", "['College teachers']", "['Brewing']", "['Sound effects books']", "['Alcoholics']", "['African American families']", "['Architecture']", "['Animal sanctuaries']", "['Nature']", "['Physicists']", "['Pigeons']", "['Southern States']", "['Europe']", "['Amazon River Region']", '131', "['Sebastopol (Calif.)']", "['Law']", "['Boats and boating']", "['Apartments']", "['Fourth of July']", "['Frontier and pioneer life']", "['Computer programmers']", "['Generals']", '292', "['Cosmetics industry']", "['Germany']", "['Photography']", "['Caterpillars']", "['College students']", "['Curiosities and wonders']", "['Acting']", "['Bus travel']", "['Beat generation']", "['Apartment houses']", "['Animals, Mythical']", "['Rock groups']", "['Life on other planets']", "['New England']", 'Oxford Paperbacks', "['Crafts & Hobbies']", "['England']", "['Psycho (Motion picture : 1960)']", "['Charriere Henri']", '208', "['Angels']", "['Presidents']", "['Love']", "['Crusades']", "['College stories']", "['Magic']", "['Human-animal relationships']", "['Design']", "['Agriculture']", "['Cocaine industry']", "['Metamorphosis']", "['Exorcism']", "['Gardening']", "['Reference']", "['Disasters']", "['Bracelets']", "['Mathematics']", "['African Americans']", "['First loves']", "['Political science']", "['Technology & Engineering']", "['Teenagers']", "['Motion picture plays']", "['Political leadership']", "['Capitalism']", "['Cults']", "['Popular culture']", "['Jews']", "['English']", "['Blacks']", "['Czech Republic']", "['Chocolate']", "['Art']", "['Music trade']", "['Beowulf']", "['English language']", "['Study Aids']", "['Abandoned mines']", "['Egyptologists']", "['Scythians']", "['Queens']", "['Yi jing']", "['Authors, Cuban']", "['Heroes']", "['Kinetic theory of gases']", "['Business women']", "['87th Precinct (Imaginary place)']", "['Botswana']", "['African Americans in radio broadcasting']", "['Black Death']", "['Animal sounds']", '199', "['Cosmology']", "['Amis, Kingsley']", "['Rock music']", "['Mormon fundamentalism']", "['Costume']", "['Sex']", "['Antisemitism']", "['Cats']", "['Anger']", "['Zoology']", "['Animals, Treatment of']", "['Farm life']", "['Americans']", "['Great Britain']", "['Authors, American']", "['Construction workers']", '2004', "['Large type books']", "['Air pilots']", "['David Eddings']", "['Gardens']", "['Candy']", "['Pets']", "['Zero (The number)']", "['Men']", '398', "['Bail bond agents']", "['Austria']", '224', 'Oxford University Press, USA', "['Books']", "['Mars (Planet)']", "['Confucianism']", "['Transportation']", "['Empiricism']", "['Survival']", "['Choice']", "['Character']", "['London (England)']", "['Cornwall (England : County)']", "['Cellists']", "['Feature films [DVD]']", "['House & Home']", "['Action']", "['Boarding schools']", "['American essays']", "['Computers']", "['Igbo (African people)']", "['Explorers']", "['Instrumental music']", "['Chick lit']", "['Chicago (Ill.)']", "['Language and languages']", "['Authors, Italian']", "['Los Angeles (Calif.)']", "['Leadership']", '361', "['Sexual behavior surveys']", '217', "['Botanique']", "['Chaleur - Transmission']", "['Aboriginal Australians']", '1992', "['Beats (Persons)']", "['Ireland']", "['Electrons']", "['George U. Wyper Fund']", "['Canterbury (England)']", "['Ballets']", "['Ex-convicts']", "['Amyotrophic lateral sclerosis']", '450', "['Cities and towns']", "['Authors, English']"]
religious = ["['RELIGION']", "['Christian saints']", "['Christian life']", "['Christianity']", "['Bibles']", "['Buddhism']"]
social_commentary = ["['Divorce']", "['Babysitters']", "['Friendship']", "['Gay men']", "['Community life']", "['Birthparents']", "['Essentialism (Philosophy)']", "['Brothers']", "['Married people']", "['Human behavior']", "['Oratory']", "['People with social disabilities']", "['Friendship in adolescence']", "['Adolescence']", "['Brothers and sisters']", "['Civil law']", "['Misogyny']", "['Divorced people']", "['City and town life']", "['Imperialism']", "['Adult education']", "['Death']", "['Family & Relationships']", "['Aged women']", "['Parenthood']", "['Consumer behavior']", "['Family life']", "['Civilization, Modern']", "['Apartheid']", "['Boys']", "['Male friendship']", "['Communal living']", "['Existentialism']", "['Dysfunctional families']", "['Divorced women']", "['Social action']"]
psychology = ["['Emotional problems']", "['Man-woman relationships']", "['Confianza en sí mismo']", "['Psychology']", "['Adjustment (Psychology)']", "['Alienation (Social psychology)']", "['Identity (Psychology)']", "['Behavior']", "['Child analysis']", "['Existential psychotherapy']"]
mythology = ["['Erinyes (Greek mythology)']", "['Mythology, Greek']", "['Theology, Doctrinal']"]
health = ["['Games & Activities']", "['Obesity']", "['Self-Help']", "['Autism']", "['Handicapped youth']", "['Mentally ill']", "['Aging']", '["Alzheimer\'s disease"]', "['Cerebrovascular disease']", "['Epidemics']", "['Dangerously mentally ill']", "['Minimal brain dysfunction in children']", "['Cooking, French']", "['Meditation']", "['Sports & Recreation']", "['Cooking']", "['Cookery']", "['Cookbooks']", "['Reducing diets']"]
fiction = ["['Sweet Valley (Imaginary place)']", "['Yoknapatawpha County (Imaginary place)']", "['Discworld (Imaginary place)']", "['Human-alien encounters']", "['Dreams']", "['Fantasy.']", "['Drenai (Imaginary place)']", "['Castle Rock (Me. : Imaginary place)']"]
literature = ["['Christmas stories']", "['Interplanetary voyages']", "['Argentine literature']", "['Country life']", "['Detective and mystery comic books, strips, etc']", "['Conspiracies']", "['Epic literature']", "['Christmas']", "['Dragons']", "['Fairy tales, English']", "['Humorous stories']", "['Canadian wit and humor']", "['Grandmothers']", "['Ghost stories, American']", "['Novelists, American']", "['Allegories']", "['Sea monsters']", "['Humorous stories, American']", "['LITERARY CRITICISM']", "['Short stories']", '["Aesop\'s fables"]', "['Comic books, strips, etc']", "['Cider house rules. (Motion picture)']", "['Literary Collections']", '["Children\'s literature, French"]', "['American wit and humor, Pictorial']", "['Graphic novels']", "['Adventure stories']", "['COMICS & GRAPHIC NOVELS']", "['Horror tales']", "['Fantasy comic books, strips, etc']", "['Comics & Graphic Novels']", "['Adventure stories, English']", "['Comedy']", '["Children\'s plays"]', "['American wit and humor']", "['Bedtime']", "['American Wit And Humour']", "['Adventure stories, American']", "['Literary Criticism']", "['Literature']", "['Horror stories.']", "['Babytime resource']", "['Fantasy']", "['Fairy tales']", "['Essays']", "['Short stories, English']", "['Humorous stories, English']", "['Horror']", "['Horror tales, American']", "['Novelists, English']", '["Children\'s stories"]', '["Children\'s stories, English"]', "['Écrivains français - 18e siècle - Biographies']", "['American literature']", "['English essays']", "['Humor']", "['Short stories, American']", "['Arthurian romances']"]
poems = ["['Englisch - Geschichte - Lyrik - Aufsatzsammlung']", "['Poets, American']", "['Poets, Chilean']"]
crime = ["['Crime investigation']", "['Crime investigations']", "['Insane, Criminal and dangerous']", "['Detective and mystery stories, English']", "['Detective and mystery stories, English.']", "['Murder']", "['Criminals']", "['True Crime']", "['Detective and mystery stories']"]

df = pd.read_csv("books_v5_sample2.csv")
lis = []
for i in range(0,6500):
    x = df.iloc[i]['categories']
    
    if x in history:
        df.at[i,'categories'] = 'History'
    elif x in contemporary:
        df.at[i,'categories'] = 'Contemporary'
    elif x in psychology:
        df.at[i,'categories'] = 'Psychology'
    elif x in mythology:
        df.at[i,'categories'] = 'Mythology'
    elif x in health:
        df.at[i,'categories'] = 'Health and Fitness'
    elif x in religious:
        df.at[i,'categories'] = 'Religion'
    elif x in social_commentary:
        df.at[i,'categories'] = 'Social Commentary'
    elif x in fiction:
        df.at[i,'categories'] = 'Fiction'
    elif x in literature:
        df.at[i,'categories'] = 'Literature'
    elif x in poems:
        df.at[i,'categories'] = 'Poems'
    elif x in poems:
        df.at[i,'categories'] = 'Crime/Thriller'
    else:
        lis.append(x)
    
df.to_csv("books_v5_sample2.csv")
print(set(lis))

# %%
lis = []
crime = ["['Insane, Criminal and dangerous']", "['Crime investigation']"]
df = pd.read_csv("books_v5_sample2.csv")
lis = ['History','Contemporary','Psychology','Mythology','Health and Fitness','Religion','Social Commentary','Fiction','Literature','Poetry','Crime/Thriller','Biography','Drama']
indices=[]

for i in range(0,6500):
    indices.append(df.iloc[i]['categories'])
    
x = list(set(indices))
for i in x:
    print(i)

# %%
#merger

#Merge

df = pd.read_csv("books_v5_sample2.csv")
df = df.astype({
   'librarything_url':str,
    'librarything_members':str,
    'librarything_avg_rating':str,
'librarything_reviews':str,
    'librarything_popularity':str,
'librarything_conversations':str,
'librarything_mentions':str,
'librarything_characters':str,
'librarything_book_summary':str,
'worldcat_url':str,
'worldcat_oclc_number':str,
'worldcat_author_more_works':str,
'amazon_link':str,
'amazon_formats_available':str,
'amazon_kindle_link':str,
'amazon_audiobook_link':str,
'amazon_hardcover_link':str,
'amazon_paperback_link':str,
'amazon_mass_market_paperback_link':str,
'amazon_audio_cd_link':str
})
df2 = pd.read_csv("books_v9_amazon.csv")
for i in range(0,6500):
    
    df.at[i,'librarything_url']  = df2.iloc[i]['librarything_url']
    df.at[i,'librarything_members']  = df2.iloc[i]['librarything_members']
    df.at[i,'librarything_avg_rating']  = df2.iloc[i]['librarything_avg_rating']
    df.at[i,'librarything_reviews']  = df2.iloc[i]['librarything_reviews']
    df.at[i,'librarything_popularity']  = df2.iloc[i]['librarything_popularity']
    df.at[i,'librarything_conversations']  = df2.iloc[i]['librarything_conversations']
    df.at[i,'librarything_mentions']  = df2.iloc[i]['librarything_mentions']
    df.at[i,'librarything_characters']  = df2.iloc[i]['librarything_characters']
    df.at[i,'librarything_book_summary']  = df2.iloc[i]['librarything_book_summary']
    df.at[i,'worldcat_url']  = df2.iloc[i]['worldcat_url']
    df.at[i,'worldcat_oclc_number']  = df2.iloc[i]['worldcat_oclc_number']
    df.at[i,'worldcat_author_more_works']  = df2.iloc[i]['worldcat_author_more_works']
    df.at[i,'amazon_link']  = df2.iloc[i]['amazon_link']
    df.at[i,'amazon_formats_available']  = df2.iloc[i]['amazon_formats_available']
    df.at[i,'amazon_kindle_link']  = df2.iloc[i]['amazon_kindle_link']
    df.at[i,'amazon_audiobook_link']  = df2.iloc[i]['amazon_audiobook_link']
    df.at[i,'amazon_hardcover_link']  = df2.iloc[i]['amazon_hardcover_link']
    df.at[i,'amazon_paperback_link']  = df2.iloc[i]['amazon_paperback_link']
    df.at[i,'amazon_mass_market_paperback_link']  = df2.iloc[i]['amazon_mass_market_paperback_link']
    df.at[i,'amazon_audio_cd_link']  = df2.iloc[i]['amazon_audio_cd_link']
    
df.to_csv("books_v10.csv")
